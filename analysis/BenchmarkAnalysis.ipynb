# %%
from Functions import get_volume_info, get_benchmark_info

#volume_info = get_volume_info()

# %%
benchmark_info, df = get_benchmark_info()
# Out:
# StatusCode for getting get-benchmarkinfo: 200

# %%
df
# Out:
#             volume_30_avg  volume_30_std  score_last_30_days  n_obs  \
# ADAUSDT          68991.04       70070.38                 1.0   17.0
# JASMYUSDT        30260.33       49523.35                 0.0   12.0
# IOTXUSDT          3648.61       11556.88                 0.0    1.0
# ICP_USDT            55.77         184.68                 0.0    1.0
# HNT_USD            382.95         725.79                 0.0    1.0
# ...                   ...            ...                 ...    ...
# SKL_USDT            18.93          78.45                 0.0    1.0
# OCEAN_USDT          37.70          89.58                 0.0    1.0
# ONE_USDT            77.94         290.87                 0.0    1.0
# XTZ_USDT            24.69         135.83                 0.0    1.0
# CRO_USDT          3541.34        3011.35                 0.0    1.0
#
#             volume_60_avg  volume_60_std  volume_90_avg  volume_90_std  \
# ADAUSDT          68991.04       70070.38       68991.04       70070.38
# JASMYUSDT        30260.33       49523.35       30260.33       49523.35
# IOTXUSDT          3648.61       11556.88        3648.61       11556.88
# ICP_USDT            55.77         184.68          55.77         184.68
# HNT_USD            382.95         725.79         382.95         725.79
# ...                   ...            ...            ...            ...
# SKL_USDT            18.93          78.45          18.93          78.45
# OCEAN_USDT          37.70          89.58          37.70          89.58
# ONE_USDT            77.94         290.87          77.94         290.87
# XTZ_USDT            24.69         135.83          24.69         135.83
# CRO_USDT          3541.34        3011.35        3541.34        3011.35
#
#             vol_mean_7days  vol_std_7days  momentum_7days_vol
# ADAUSDT                NaN            NaN                 NaN
# JASMYUSDT              NaN            NaN                 NaN
# IOTXUSDT               NaN            NaN                 NaN
# ICP_USDT               NaN            NaN                 NaN
# HNT_USD                NaN            NaN                 NaN
# ...                    ...            ...                 ...
# SKL_USDT               NaN            NaN                 NaN
# OCEAN_USDT             NaN            NaN                 NaN
# ONE_USDT               NaN            NaN                 NaN
# XTZ_USDT               NaN            NaN                 NaN
# CRO_USDT               NaN            NaN                 NaN
#
# [295 rows x 11 columns]
