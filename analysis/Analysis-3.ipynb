# %%
# DOWNLOAD AND SHOW OUTPUT FROM TOTAL MULTIPROCESSING
from Functions import download_show_output
import pandas as pd
pd.set_option('display.max_rows', None)

minimum_event_number = 30
minimum_coin_number = 5
mean_threshold = 1.5
lb_threshold = -15
frequency_threshold = 2
group_coins = True
best_coins_volatility = 1
std_multiplier = 3
search_parameters = {'min_event_n': minimum_event_number, 'mean_thresh': mean_threshold,
                     'group': group_coins, 'std_multpl': std_multiplier}

output, complete_info = download_show_output(minimum_event_number=minimum_event_number, minimum_coin_number=minimum_coin_number,
                                      mean_threshold=mean_threshold, lb_threshold=lb_threshold, frequency_threshold=frequency_threshold,
                                       group_coins=group_coins, best_coins_volatility=best_coins_volatility, std_multiplier=std_multiplier)
df = pd.DataFrame(output).transpose()
df.sort_values(by=['upper_bound'], ascending=False)
#df.sort_values(by=['lower_bound'], ascending=False)
# Out:
# Downloading /Users/albertorainieri/Projects/Personal/analysis/analysis_json/analysis.json
# Download completed in 6.7 seconds
#                                             mean   std  n_coins  n_events  \
# buy_vol_30m:0.85/vol_6h:20/timeframe:4320   3.36  5.74     27.0      34.0
# buy_vol_30m:0.85/vol_60m:30/timeframe:2880  2.50  3.69     17.0      33.0
# buy_vol_5m:0.75/vol_24h:50/timeframe:360    1.80  3.82     27.0      42.0
# buy_vol_3h:0.65/vol_60m:10/timeframe:4320   1.94  3.56    256.0    1104.0
# buy_vol_6h:0.75/vol_30m:50/timeframe:1440   1.61  3.04     36.0      59.0
# buy_vol_6h:0.85/vol_3h:6/timeframe:4320     2.06  2.20     13.0      37.0
# buy_vol_3h:0.85/vol_3h:6/timeframe:4320     1.72  2.35     17.0      44.0
# buy_vol_3h:0.85/vol_6h:6/timeframe:1440     2.30  1.66     10.0      31.0
# buy_vol_6h:0.85/vol_15m:30/timeframe:4320   1.55  2.40     27.0      70.0
# buy_vol_3h:0.85/vol_60m:20/timeframe:1440   1.93  1.97     14.0      33.0
# buy_vol_6h:0.85/vol_5m:50/timeframe:4320    1.54  2.35     34.0      98.0
# buy_vol_6h:0.85/vol_15m:50/timeframe:4320   1.84  2.01     15.0      42.0
# buy_vol_24h:0.75/vol_3h:6/timeframe:4320    1.53  2.32     17.0      35.0
# buy_vol_6h:0.85/vol_30m:30/timeframe:4320   1.68  2.02     14.0      40.0
# buy_vol_6h:0.85/vol_60m:15/timeframe:4320   1.64  2.03     15.0      42.0
# buy_vol_6h:0.85/vol_60m:20/timeframe:1440   1.86  1.79     12.0      31.0
# buy_vol_6h:0.85/vol_30m:20/timeframe:4320   1.52  1.95     20.0      56.0
#
#                                             upper_bound  lower_bound
# buy_vol_30m:0.85/vol_6h:20/timeframe:4320          9.10        -2.38
# buy_vol_30m:0.85/vol_60m:30/timeframe:2880         6.19        -1.19
# buy_vol_5m:0.75/vol_24h:50/timeframe:360           5.62        -2.02
# buy_vol_3h:0.65/vol_60m:10/timeframe:4320          5.50        -1.62
# buy_vol_6h:0.75/vol_30m:50/timeframe:1440          4.65        -1.43
# buy_vol_6h:0.85/vol_3h:6/timeframe:4320            4.26        -0.14
# buy_vol_3h:0.85/vol_3h:6/timeframe:4320            4.07        -0.63
# buy_vol_3h:0.85/vol_6h:6/timeframe:1440            3.96         0.64
# buy_vol_6h:0.85/vol_15m:30/timeframe:4320          3.95        -0.85
# buy_vol_3h:0.85/vol_60m:20/timeframe:1440          3.90        -0.04
# buy_vol_6h:0.85/vol_5m:50/timeframe:4320           3.89        -0.81
# buy_vol_6h:0.85/vol_15m:50/timeframe:4320          3.85        -0.17
# buy_vol_24h:0.75/vol_3h:6/timeframe:4320           3.85        -0.79
# buy_vol_6h:0.85/vol_30m:30/timeframe:4320          3.70        -0.34
# buy_vol_6h:0.85/vol_60m:15/timeframe:4320          3.67        -0.39
# buy_vol_6h:0.85/vol_60m:20/timeframe:1440          3.65         0.07
# buy_vol_6h:0.85/vol_30m:20/timeframe:4320          3.47        -0.43

# %%
#complete_info['buy_vol_6h:0.85/vol_5m:50/timeframe:4320']

# %%
from Functions import supervised_analysis

test_size = 0.5
complete_info_path = '/Users/albertorainieri/Projects/Personal/analysis/complete_info/info-2023-11-3-min_event_n:30-mean_thresh:1.5-group:True-std_multpl:3-226.json'
#complete_info_path = None
target_variable='max'

if complete_info_path:
    complete_info = None
    search_parameters = None

supervised_analysis(complete_info=complete_info, complete_info_path=complete_info_path, search_parameters=search_parameters,
                        target_variable=target_variable, test_size=test_size)
# Out:
# complete_info_path PROVIDED. Loading data locally
# Total Number of combinations: 864
# Found new Acc Score:  0
# 10 percent of Data covered
# BEST_ACC_SCORE:  0
# Total Number of combinations: 864
# Found new Acc Score:  0
# 10 percent of Data covered
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/albertorainieri/Projects/Personal/analysis/Analysis-3.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/Users/albertorainieri/Projects/Personal/analysis/Analysis-3.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     complete_info = None
#      <a href='vscode-notebook-cell:/Users/albertorainieri/Projects/Personal/analysis/Analysis-3.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     search_parameters = None
# ---> <a href='vscode-notebook-cell:/Users/albertorainieri/Projects/Personal/analysis/Analysis-3.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> supervised_analysis(complete_info=complete_info, complete_info_path=complete_info_path, search_parameters=search_parameters,
#      <a href='vscode-notebook-cell:/Users/albertorainieri/Projects/Personal/analysis/Analysis-3.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>                         target_variable=target_variable, test_size=test_size)
#
# File ~/Projects/Personal/analysis/Functions.py:2545, in supervised_analysis(complete_info, complete_info_path, search_parameters, target_variable, test_size)
#    2542             y_test.append(int(cl_key))
#    2543             break
# -> 2545 df_cm = train_model_xgb(X_train, X_test, y_train, y_test, classifier_strings, event_key)
#    2547 ax= plt.subplot()
#    2548 sn.heatmap(df_cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation
#
# File ~/Projects/Personal/analysis/Helpers.py:871, in train_model_xgb(X_train, X_test, y_train, y_test, classifier_strings, event_key)
#     851         SKIP_10 = True
#     853 model = XGBClassifier(
#     854             n_estimators=n_estimators,
#     855             gamma=gamma,
#    (...)
#     868             alpha=alpha,
#     869             n_jobs=-1)
# --> 871 model.fit(X_train,y_train)
#     873 # Predict
#     874 y_pred = model.predict(X_test)
#
# File /opt/homebrew/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/xgboost/sklearn.py:1515, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1487 (
#    1488     model,
#    1489     metric,
#    (...)
#    1494     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1495 )
#    1496 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1497     missing=self.missing,
#    1498     X=X,
#    (...)
#    1512     feature_types=self.feature_types,
#    1513 )
# -> 1515 self._Booster = train(
#    1516     params,
#    1517     train_dmatrix,
#    1518     self.get_num_boosting_rounds(),
#    1519     evals=evals,
#    1520     early_stopping_rounds=early_stopping_rounds,
#    1521     evals_result=evals_result,
#    1522     obj=obj,
#    1523     custom_metric=metric,
#    1524     verbose_eval=verbose,
#    1525     xgb_model=model,
#    1526     callbacks=callbacks,
#    1527 )
#    1529 if not callable(self.objective):
#    1530     self.objective = params["objective"]
#
# File /opt/homebrew/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/homebrew/lib/python3.11/site-packages/xgboost/core.py:2050, in Booster.update(self, dtrain, iteration, fobj)
#    2046 self._assign_dmatrix_features(dtrain)
#    2048 if fobj is None:
#    2049     _check_call(
# -> 2050         _LIB.XGBoosterUpdateOneIter(
#    2051             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2052         )
#    2053     )
#    2054 else:
#    2055     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
