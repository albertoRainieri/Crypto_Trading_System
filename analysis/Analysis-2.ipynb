# %%
from Functions import plot_live_timeseries
risk_management_path = "/Users/albertorainieri/Projects/Personal/analysis/riskmanagement_backup/riskmanagement-2023-9-27-[50, 35, 25, 15, 5]-3-212.json"
plot_live_timeseries(risk_management_path, filter_live=False, filter_best=50)

# %%
# EARLY VALIDATION ANALYSIS
# ANALYZE THE RISKMANAGEMENT OF ALL KEYS FROM INFO UNTIL A CERTAIN DATE
from Functions import earlyValidation
import pandas as pd
from datetime import datetime
pd.set_option('display.max_rows', None)

# minimum_event_number_list MUST BE a list IN REVERSE ORDER
minimum_event_number_list = [50, 35, 25, 15, 10, 5]
minimum_coin_number = 0
mean_threshold = 3
lb_threshold = -15
frequency_threshold = 1
group_coins = False
best_coins_volatility = 5
early_validation = datetime(2023,9,27)

optimized_gain_threshold = 5
mean_gain_threshold = 3
riskmanagement_conf = (minimum_event_number_list, minimum_coin_number, mean_threshold, lb_threshold, frequency_threshold, group_coins, best_coins_volatility)
riskmanagement_path = '/Users/albertorainieri/Projects/Personal/analysis/riskmanagement_backup/riskmanagement-2023-9-30-[50, 35, 25, 15, 10, 5]-3-earlyvalidation-3stdmultiplier-470.json'
#riskmanagement_path = False
std_multiplier = 3
OPTIMIZED=True
DISCOVER=False

df = earlyValidation(minimum_event_number_list, minimum_coin_number, mean_threshold, lb_threshold, frequency_threshold, optimized_gain_threshold,
                     mean_gain_threshold, group_coins, best_coins_volatility, early_validation, OPTIMIZED, DISCOVER, riskmanagement_path, std_multiplier)
df
# Out:
# RiskManagement Path is provided
# Loading analysis.json for both scenarios: OPTIMIZED or not
# OPTIMIZED ANALYSIS
# Loading data from analysis.json
# No need to update optimized_results for buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# No need to update optimized_results for buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# No need to update optimized_results for buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# No need to update optimized_results for buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# No need to update optimized_results for buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# No need to update optimized_results for buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# No need to update optimized_results for buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# No need to update optimized_results for buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# No need to update optimized_results for buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# No need to update optimized_results for buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# No need to update optimized_results for buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# No need to update optimized_results for buy_vol_3h:0.85/vol_60m:20/timeframe:1440/vlty:6
# No need to update optimized_results for buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# No need to update optimized_results for buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# No need to update optimized_results for buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# No need to update optimized_results for buy_vol_60m:0.75/vol_6h:20/timeframe:2880/vlty:3
# No need to update optimized_results for buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# No need to update optimized_results for buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# Json File Updated: /Users/albertorainieri/Projects/Personal/analysis/optimized_results_backup/optimized_results-2023-9-30-[50, 35, 25, 15, 10, 5]-3-earlyvalidation-3stdmultiplier-470.json
# the profit of the entire timeseries is 7.63% with 299 events
# the post profit is 0.83% with 91 events
# Positive events: 137
# Negative events: 162
# Biggest Drop: 145.7 at 2023-10-17T04:59:05.695902
# Positive events: 137
# Negative events: 162
# Biggest Drop: 145.7 at 2023-10-17T04:59:05.695902
#                           event  mean_series  mean_event  balance  \
# 0    2023-05-24T05:59:02.689721     0.079037    0.079037  1007.90
# 1    2023-05-24T05:59:02.689721     0.076689    0.074341  1015.33
# 2    2023-06-04T14:26:02.654283     0.096478    0.136057  1028.94
# 3    2023-06-04T14:26:02.654283     0.072794    0.001740  1029.11
SDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 1       ARPAUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 2       LUNCUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 3       LUNCUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 4      ADAUPUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 5      SUSHIUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 6        GNOUSDT  buy_vol_3h:0.85/vol_60m:20/timeframe:1440/vlty:6
# 7       STPTUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 8       POLSUSDT    buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# 9       BONDUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 10      API3USDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 11      VTHOUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 12      DATAUSDT  buy_vol_3h:0.85/vol_60m:20/timeframe:1440/vlty:6
# 13      PROMUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 14       OXTUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 15       BNTUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 16      ARDRUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 17    BADGERUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 18       GLMUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 19       GLMUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 20      FIROUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 21      HIFIUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 22       BLZUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 23       BLZUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 24       BLZUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 25     AERGOUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 26      COMPUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 27       MDTUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 28      COMPUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 29      COMPUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 30      COMPUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 31       LTCUSDT  buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# 32       LTCUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 33       LTCUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 34       SNTUSDT  buy_vol_60m:0.75/vol_6h:20/timeframe:2880/vlty:3
# 35       XVGUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 36       XVGUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 37       WANUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 38      RAREUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 39       XVGUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 40       XVGUSDT  buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# 41       FUNUSDT    buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# 42       FUNUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 43      TROYUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 44      TROYUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 45      TROYUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 46      TROYUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 47       VIBUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 48       EURUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 49       EURUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 50       EURUSDT  buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# 51       XVGUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 52       XVGUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 53       AVAUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 54       ILVUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 55       ILVUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 56       ILVUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 57       ASTUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 58       ASTUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 59      DEGOUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 60      PROSUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 61       PNTUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 62       PNTUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 63       REQUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 64       PNTUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 65      CTXCUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 66      TROYUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 67      TROYUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 68       LTOUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 69       LTOUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 70   AUCTIONUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 71   AUCTIONUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 72      PONDUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 73      BIFIUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 74      FARMUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 75      LOOMUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 76       WRXUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 77       WRXUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 78      POWRUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 79      POWRUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 80     STEEMUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 81      ARDRUSDT  buy_vol_60m:0.75/vol_6h:20/timeframe:2880/vlty:3
# 82       CVCUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 83       CVCUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 84       ONGUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 85       ONGUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 86       ZRXUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 87       ZRXUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 88       ZRXUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 89       GNOUSDT    buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# 90     1INCHUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 91    PUNDIXUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 92    PUNDIXUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 93       WINUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 94       JSTUSDT  buy_vol_60m:0.75/vol_6h:20/timeframe:2880/vlty:3
# 95      STMXUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 96       JUVUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 97       JUVUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 98       OGNUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 99       OGNUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 100      OGNUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 101     STPTUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 102      ELFUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 103     PROMUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 104     CTXCUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 105      ELFUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 106     WNXMUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 107     MOVRUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 108     MOVRUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 109      RLCUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 110      YGGUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 111      YGGUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 112      YGGUSDT  buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# 113      LTOUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 114      FIOUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 115      TRUUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 116      TRUUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 117      TRUUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 118      TKOUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 119      TKOUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 120      RLCUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 121    SPELLUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 122      C98USDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 123     VIDTUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 124     VIDTUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 125      LPTUSDT  buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# 126      LPTUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 127      LPTUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 128     HIGHUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 129      LPTUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 130      BLZUSDT  buy_vol_60m:0.75/vol_6h:20/timeframe:2880/vlty:3
# 131     POLSUSDT  buy_vol_3h:0.85/vol_60m:20/timeframe:1440/vlty:6
# 132      BLZUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 133      ONEUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 134      ONEUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 135    FRONTUSDT  buy_vol_3h:0.85/vol_60m:20/timeframe:1440/vlty:6
# 136      ORNUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 137      UFTUSDT    buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# 138      BALUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 139     WNXMUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 140     DEXEUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 141      TRUUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 142      TRUUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 143      TRUUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 144      AVAUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 145     NULSUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 146     REEFUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 147     REEFUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 148     REEFUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 149      QKCUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 150      QKCUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 151      XTZUSDT  buy_vol_60m:0.75/vol_6h:20/timeframe:2880/vlty:3
# 152     BETHUSDT  buy_vol_3h:0.85/vol_60m:20/timeframe:1440/vlty:6
# 153  BTCDOWNUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 154  BTCDOWNUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 155      REIUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 156      REIUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 157      REIUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 158      FLMUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 159      FLMUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 160      FLMUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 161    MULTIUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 162    MULTIUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 163    MULTIUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 164   ALPACAUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 165      ASRUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 166      FISUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 167      FISUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 168      COSUSDT    buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# 169     DEGOUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 170      ELFUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 171      REIUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 172      REIUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 173      OAXUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 174      ASRUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 175     LOOMUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 176   ALPINEUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 177     VITEUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 178     VITEUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 179     VITEUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 180     VITEUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 181     LOOMUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 182     LOOMUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 183    STRAXUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 184      ZRXUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 185      XEMUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 186      XEMUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 187      XEMUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 188      EPXUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 189      EPXUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 190    SPELLUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 191    SPELLUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 192     LOOMUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 193     LOOMUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 194     LOOMUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 195    FRONTUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 196    FRONTUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 197     STPTUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 198     STPTUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 199     STPTUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 200      FLMUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 201     HARDUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 202     CITYUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 203     CITYUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 204     CITYUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 205     MOVRUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 206     MOVRUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 207     MOVRUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 208      MLNUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 209      MLNUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 210      MLNUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 211     BICOUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 212     BICOUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 213     LOOMUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 214     LOOMUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 215     LOOMUSDT  buy_vol_5m:0.65/vol_15m:50/timeframe:4320/vlty:1
# 216      JSTUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 217      JSTUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 218      JSTUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 219      JSTUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 220      SUNUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 221     DOCKUSDT    buy_vol_3h:0.65/vol_6h:20/timeframe:720/vlty:5
# 222     DOCKUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 223      DGBUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 224     MBOXUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 225     QTUMUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 226     QTUMUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 227      ASRUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 228      CVCUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 229      XNOUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 230      JUVUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 231      ADXUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 232      JUVUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 233      JUVUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 234      ADXUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 235   ALPACAUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 236   ALPACAUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 237   ALPACAUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 238   ALPACAUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 239      ACMUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 240      ACMUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 241      QKCUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 242     ARDRUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 243     QTUMUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 244      PSGUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 245      ICXUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 246      ICXUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 247     CITYUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 248      REIUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 249     LQTYUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 250    SUSHIUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 251    SUPERUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 252    SUPERUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 253     DEGOUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 254     DEGOUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 255      GNOUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 256        TUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 257      RIFUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 258      DIAUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 259      RIFUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 260     DOCKUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 261     DOCKUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 262     DOCKUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 263     DOCKUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 264      DGBUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 265     VITEUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 266     VITEUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 267     VITEUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 268      VIBUSDT   buy_vol_3h:0.75/vol_60m:10/timeframe:720/vlty:3
# 269      VIBUSDT   buy_vol_3h:0.75/vol_60m:15/timeframe:720/vlty:3
# 270      VIBUSDT   buy_vol_3h:0.75/vol_30m:30/timeframe:720/vlty:3
# 271    AERGOUSDT   buy_vol_30m:0.65/vol_3h:50/timeframe:360/vlty:5
# 272      VIBUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 273      VIBUSDT   buy_vol_5m:0.65/vol_30m:30/timeframe:720/vlty:1
# 274      VIBUSDT  buy_vol_5m:0.65/vol_30m:30/timeframe:4320/vlty:1
# 275      WINUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 276      WINUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 277     WNXMUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 278     WNXMUSDT  buy_vol_15m:0.85/vol_3h:12/timeframe:4320/vlty:7
# 279      RIFUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 280    STEEMUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 281    STEEMUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 282      QKCUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 283      ACHUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 284      ACHUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 285      ACHUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 286    STEEMUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 287     POWRUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 288     POWRUSDT  buy_vol_30m:0.75/vol_6h:10/timeframe:2880/vlty:2
# 289     POWRUSDT  buy_vol_30m:0.75/vol_6h:12/timeframe:4320/vlty:2
# 290      STGUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 291      PYRUSDT  buy_vol_60m:0.65/vol_6h:12/timeframe:2880/vlty:2
# 292      ADXUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
# 293    LAZIOUSDT  buy_vol_5m:0.85/vol_30m:50/timeframe:2880/vlty:4
# 294     DEXEUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 295     DEXEUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 296      FIOUSDT   buy_vol_3h:0.65/vol_3h:20/timeframe:2880/vlty:4
# 297      FIOUSDT   buy_vol_6h:0.65/vol_3h:20/timeframe:1440/vlty:4
# 298     DEXEUSDT  buy_vol_5m:0.85/vol_60m:50/timeframe:2880/vlty:4
#
#        buy_price   exit_price              timestamp_exit    max_price  ...  \
# 0       0.100080     0.107990  2023-05-24T15:36:02.796321     0.107990  ...
# 1       0.100080     0.107520  2023-05-26T15:36:02.390903     0.120500  ...
# 2       0.000098     0.000111  2023-06-05T00:03:02.440406     0.000115  ...
# 3       0.000098     0.000098  2023-06-07T00:04:02.230400     0.000115  ...
# 4       0.088000     0.107000  2023-06-11T22:08:02.896353     0.109000  ...
# 5       0.572000     0.572000  2023-06-11T22:10:02.849730     0.595000  ...
# 6     110.400000   109.500000  2023-06-11T12:53:02.532959   110.400000  ...
# 7       0.035010     0.034760  2023-06-12T17:06:02.835604     0.035730  ...
# 8       0.274000     0.272000  2023-06-13T14:56:02.330712     0.279000  ...
# 9       2.847000     2.802000  2023-06-13T18:55:02.285420     2.892000  ...
# 10      0.973000     0.941000  2023-06-13T22:41:02.365527     0.973000  ...
# 11      0.001003     0.000965  2023-06-17T19:08:02.430731     0.001007  ...
# 12      0.023020     0.025230  2023-06-19T12:05:02.801699     0.027060  ...
# 13      4.530000     4.270000  2023-06-21T01:46:02.410820     4.530000  ...
# 14      0.056400     0.054300  2023-06-21T02:19:02.582778     0.061400  ...
# 15      0.356500     0.382700  2023-06-21T19:03:02.435734     0.385600  ...
# 16      0.075300     0.076400  2023-06-22T07:23:02.405182     0.078300  ...
# 17      2.264000     2.295000  2023-06-24T05:12:02.159465     2.328000  ...
# 18      0.196900     0.188700  2023-06-25T22:02:02.789490     0.219700  ...
# 19      0.196900     0.188700  2023-06-25T22:02:02.789490     0.219700  ...
# 20      1.590000     1.563000  2023-06-24T23:23:02.551092     1.590000  ...
# 21      0.318000     0.316900  2023-06-26T11:42:02.548426     0.322100  ...
# 22      0.059200     0.057600  2023-06-27T02:24:02.729797     0.060200  ...
# 23      0.059200     0.057600  2023-06-27T02:24:02.729797     0.060200  ...
# 290   1.3000    0.8110  0.4320  0.5490  0.5032   0.4205  0.5350  0.3565
# 291   6.9890    0.5610  0.5385  0.4660  0.5568   0.5179  0.4235  0.5743
# 292   0.0590    0.2645  0.5200  0.5250  0.5505   0.5375  0.5460  0.2950
# 293   0.2920    1.4755  0.5070  0.6129  0.7014   0.3878  0.3989  0.6785
# 294   1.7505    2.8065  0.4340  0.3171  0.5290   0.6995  0.6640  0.3837
# 295   1.7095    2.8525  0.4630  0.4300  0.6000   0.5911  0.4837  0.4650
# 296   0.1780    0.1720  0.6485  0.4015  0.3200   0.5650  0.3495  0.3100
# 297   0.1780    0.1720  0.5560  0.3530  0.3957   0.5980  0.4357  0.4045
# 298   2.6730    1.0155  0.4000  0.4250  0.4706   0.8860  0.1670  0.4165
#
#      buy_3d  buy_7d
# 0    0.6305  0.3440
# 1    0.6305  0.3440
# 2    0.4450  0.5080
# 3    0.4450  0.5080
# 4    0.4885     NaN
# 5    0.6480     NaN
# 6    0.4885     NaN
# 7    0.5200     NaN
# 8    0.6025  0.5085
# 9    0.4081  0.3668
# 10   0.7105  0.4119
# 11   0.5963  0.6475
# 12   0.5050  0.5770
# 13   0.2500  0.2500
# 14   0.5630  0.6155
# 15   0.5243  0.6500
# 16   0.8237  0.7448
# 17   0.5155  0.9486
# 18   0.9406  0.3828
# 19   0.9406  0.3828
# 20   0.5463  0.7229
# 21   0.4158  0.3725
# 22   0.5038  0.3960
# 23   0.5038  0.3960
# 24   0.5038  0.3960
# 25   0.6725  0.7259
# 26   0.4480  0.3947
# 27   0.6755  0.3215
# 28   0.5300  0.2900
# 29   0.4690  0.1768
# 30   0.4690  0.1768
# 31   0.5325  0.4626
# 32   0.5211  0.4590
# 33   0.5211  0.4590
# 34   0.4948  0.5335
# 35   0.4465  0.5100
# 36   0.4465  0.5100
# 37   0.0660  0.5875
# 38   0.4694  0.3255
# 39   0.7195  0.6068
# 40   0.7195  0.6068
# 41   0.4153  0.5290
# 42   0.7957  0.5885
# 43   0.3810  0.2600
# 44   0.4317  0.4079
# 45   0.4965  0.3910
# 46   0.3600  0.4000
# 47   0.3365  0.2971
# 48   0.3947  0.4838
# 49   0.3947  0.4838
# 50   0.3947  0.4838
# 51   0.4450  0.4100
# 52   0.4450  0.4100
# 53   0.6825  0.2640
# 54   0.3720  0.4616
# 55   0.3660  0.4900
# 56   0.3650  0.4915
# 57   0.5325  0.5575
# 58   0.5000  0.5562
# 59   0.3189  0.6885
# 60   0.5255  0.2437
# 61   0.3705  0.3680
# 62   0.4870  0.4330
# 63   0.1500  0.6053
# 64   0.7811  0.0000
# 65   0.4850  0.5555
# 66   0.3910  0.4405
# 67   0.3910  0.4405
# 68   0.5680  0.6820
# 69   0.5590  0.6190
# 70   0.3715  0.5275
# 71   0.4350  0.6500
# 72   0.4847  0.4733
# 73   0.7085  0.8576
# 74   0.5238  0.3287
# 75   0.7419  0.6107
# 76   0.3575  0.3125
# 77   0.3555  0.3115
# 78   0.6400  0.5745
# 79   0.6400  0.5745
# 80   0.1300  0.5957
# 81   0.6235  0.3950
# 82   0.2645  0.4041
# 83   0.2645  0.4041
# 84   0.1733  0.2800
# 85   0.1733  0.2800
# 86   0.4905  0.7200
# 87   0.4905  0.7200
# 88   0.3415  0.4147
# 89   0.3190  0.2315
# 90   0.3614  0.6321
# 91   0.4600  0.5037
# 92   0.4620  0.5521
# 93   0.1595  0.2295
# 94   0.7770  0.3043
# 95   0.4340  0.3638
# 96   0.5385  0.4795
# 97   0.5405  0.4805
# 98   0.4670  0.4216
# 99   0.4670  0.4216
# 100  0.4670  0.4235
# 101  0.8065  0.8655
# 102  0.2435  0.3205
# 103  0.7735  0.5900
# 104  0.5370  0.4221
# 105  0.0000  0.0000
# 106  0.5852  0.0465
# 107  0.5315  0.4160
# 108  0.4774  0.2816
# 109  0.1323  0.4995
# 110  0.4950  0.3955
# 111  0.4950  0.3955
# 112  0.4950  0.3955
# 113  0.4775  0.4895
# 114  0.6250  0.6459
# 115  0.2970  0.5120
# 116  0.2984  0.5140
# 117  0.2990  0.5180
# 118  0.2644  0.5240
# 119  0.2644  0.5240
# 120  0.8000  0.3387
# 121  0.3740  0.4190
# 122  0.4560  0.5690
# 123  0.4540  0.6590
# 124  0.4432  0.6560
# 125  0.5290  0.2360
# 126  0.5155  0.2088
# 127  0.5155  0.2088
# 128  0.6380  0.7252
# 129  0.5045  0.1520
# 130  0.3711  0.5142
# 131  0.5225  0.5186
# 132  0.2705  0.5410
# 133  0.4585  0.4665
# 134  0.4050  0.4645
# 135  0.5129  0.1610
# 136  0.3659  0.3933
# 137  0.2790  0.4340
# 138  0.4740  0.4080
# 139  0.3900  0.2465
# 140  0.1400  0.4195
# 141  0.3520  0.6675
# 142  0.3490  0.6560
# 143  0.3460  0.6420
# 144  0.6921  0.3225
# 145  0.3340  0.6005
# 146  0.3380  0.7210
# 147  0.5124  0.6771
# 148  0.5124  0.6771
# 149     NaN  0.6653
# 150     NaN  0.6653
# 151  0.4920  0.7100
# 152  0.4945  0.4015
# 153  0.7310  0.5295
# 154  0.5968  0.5480
# 155  0.6870  0.6526
# 156  0.7180  0.6245
# 157  0.7180  0.6245
# 158  0.4825  0.5480
# 159  0.3835  0.3905
# 160  0.3579  0.0614
# 161  0.6270  0.5360
# 162  0.6270  0.5360
# 163  0.6270  0.5360
# 164  0.5105  1.0000
# 165  0.4195  0.5324
# 166  0.7461  0.6828
# 167  0.7461  0.6828
# 168  0.5571  0.4130
# 169  0.5520  0.6048
# 170  0.5968  0.4245
# 171  0.6145  0.3295
# 172  0.5570  0.3710
# 173  0.4215  0.6595
# 174  0.4340  0.5310
# 175  0.3386  0.7239
# 176  0.2256  0.3750
# 177  0.6154  0.3750
# 178  0.6000  0.0000
# 179  0.4750  0.5530
# 180  0.4300  0.5995
# 181  0.4916  0.0911
# 182  0.4945  0.0962
# 183  0.7365  0.4605
# 184  0.4805  0.3120
# 185  0.5105  0.4142
# 186  0.5100  0.4185
# 187  0.5100  0.4185
# 188  0.3924  0.8235
# 189  0.4657  0.1940
# 190  0.7975  0.5200
# 191  0.7975  0.5200
# 192  0.4545  0.7667
# 193  0.4395  0.8150
# 194  0.4395  0.8150
# 195  0.5184  0.3905
# 196  0.5184  0.3905
# 197  0.3514  0.5200
# 198  0.5940  0.6253
# 199  0.5940  0.6253
# 200  0.3929  0.3785
# 201  0.6558  0.2375
# 202  0.5460  0.3979
# 203  0.5460  0.3875
# 204  0.5460  0.3875
# 205  0.5680  0.7815
# 206  0.5870  0.7845
# 207  0.5870  0.7845
# 208  0.6045  0.4179
# 209  0.6010  0.4329
# 210  0.6010  0.4329
# 211  0.5075  0.5900
# 212  0.4500  0.5860
# 213  0.4930  0.5500
# 214  0.4930  0.5500
# 215  0.4930  0.5500
# 216  0.1750  0.3740
# 217  0.4145  0.7060
# 218  0.4675  0.5500
# 219  0.6579  0.6805
# 220  0.3310  1.0000
# 221  0.5595  0.4915
# 222  0.5400  0.3185
# 223  0.4028  0.2195
# 224  0.5290  0.2859
# 225  0.5533  0.3857
# 226  0.5252  0.4000
# 227  0.5035  0.5090
# 228  1.0000  0.4986
# 229  0.8485  0.8940
# 230  0.6727  0.0000
# 231  0.8850  0.7180
# 232  0.2320  0.5615
# 233  0.4075  0.4400
# 234  0.4064  0.9400
# 235  0.7400  0.6720
# 236  0.7400  0.6415
# 237  0.3945  0.8500
# 238  0.3575  0.7915
# 239  0.5735  0.7045
# 240  0.4220  0.3810
# 241  0.0000  0.3320
# 242  0.3570  0.7205
# 243  0.1405  0.3268
# 244  0.6240  0.5490
# 245  0.7255  0.2610
# 246  0.6535  0.3110
# 247  0.6800  0.2283
# 248  0.3330  0.5785
# 249  0.6435  0.4705
# 250  0.5410  0.6200
# 251  0.2460  0.4220
# 252  0.2110  0.5805
# 253  0.2915  0.8153
# 254  0.4643  0.3400
# 255  0.6600  0.5132
# 256  0.3780  0.4230
# 257  0.2730  0.4140
# 258  0.8615  0.3035
# 259  0.2980  0.3315
# 260  0.3100  0.2815
# 261  0.5455  0.4415
# 262  0.7188  0.8747
# 263  0.7188  0.8747
# 264  0.5632  0.2472
# 265  0.1665  0.4221
# 266  0.1665  0.4215
# 267  0.1665  0.4215
# 268  0.4330  0.6595
# 269  0.4433  0.6460
# 270  0.4460  0.6450
# 271  0.7070  0.3200
# 272     NaN  0.6680
# 273  0.3985  0.2560
# 274  0.3985  0.2560
# 275  0.5085  0.3465
# 276  0.5520  0.3605
# 277  0.5455  0.4990
# 278  0.2120  0.6514
# 279  0.5705  0.6765
# 280  0.3250  0.5630
# 281  0.3250  0.5630
# 282  0.7010  0.2135
# 283  0.3260  0.6876
# 284  0.3400  0.5900
# 285  0.3400  0.5900
# 286  0.4000  0.3000
# 287  0.2835  0.4448
# 288  0.2040  0.6490
# 289  0.2040  0.6490
# 290  0.2795  0.6960
# 291  0.4460  0.7020
# 292  0.5294  0.4870
# 293  0.7581  0.5425
# 294  0.3590  0.3440
# 295  0.3195  0.3835
# 296  0.4920  0.5180
# 297  0.5105  0.5830
# 298  0.5400  0.3115
#
# [299 rows x 35 columns]

# %%
from Functions import PriceVariation_analysis
model_type = 'linear_regression'
model_type = 'svc'
model_type = 'xgboost'
decision_variable_target = 'max_price' #mean_event, max_price, min_price
test_size=0.25
PriceVariation_analysis(df, model_type=model_type, decision_variable_target=decision_variable_target, test_size=test_size)

# %%
from Functions import analyzeRiskManagementPerformance

riskmanagement_path = "/Users/albertorainieri/Projects/Personal/analysis/riskmanagement_backup/riskmanagement-2023-9-30-[50, 35, 25, 15, 10, 5]-3-earlyvalidation-3stdmultiplier-470.json"
OPTIMIZED=True
DISCOVER=False

event_investment_amount=100


df, biggest_drop, biggest_drop_date, positive_outcome, negative_outcome, PERFORMANCE_SCENARIOS = analyzeRiskManagementPerformance(riskmanagement_path, OPTIMIZED, DISCOVER, event_investment_amount)
import pandas as pd
pd.set_option('display.max_rows', 1000)
print(f'Positive events: {positive_outcome}')
print(f'Negative events: {negative_outcome}')
print(f'Biggest Drop: {biggest_drop} at {biggest_drop_date}')

df

# %%
import json
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from datetime import datetime, timedelta
import requests
import os, sys
from time import sleep
import pytz
#from scipy.stats import pearsonr
import pandas as pd
from time import time
from Functions_getData import getData
from multiprocessing import Pool, Manager
from copy import copy
from random import randint
import shutil
import re
from Helpers import round_, get_volatility, data_preparation, retrieve_datetime_for_load_data, updateData_for_load_data, get_date_key, load_data, get_benchmark_info, get_dynamic_volume_avg, get_substring_between, load_analysis_json_info, updateAnalysisJson, pooled_standard_deviation, getsubstring_fromkey, sort_files_in_json_dir
from sklearn.svm import SVR  # Support Vector Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sn
from typing import Literal

DecisionVariables = ['mean_event', 'max_price', 'min_price']

def PriceVariation_analysis(df, model_type='svc', decision_variable_target: DecisionVariables = 'mean_event', test_size=0.2):

    # Identify Decision and Output variables
    all_columns = list(df.columns)
    #selected_columns = [column for column in all_columns if 'price_%' in column or 'vol' in column or 'buy' in column]
    selected_columns = [column for column in all_columns if 'price_%' in column or 'vol' in column or 'buy' in column]
    decision_variables = df[selected_columns]

    # define decision variable, only 'mean_event' is normalized, max_price and min_price need to be normalized
    if decision_variable_target != 'mean_event':
        output_variable = np.array((df[decision_variable_target] - df['buy_price']) / df['buy_price'])
    else:
        output_variable = np.array(df[decision_variable_target])

    #output_variable = np.array(df[decision_variable_target])
    #print(len(output_variable))

    # Filter out NaN values
    X_withnan = np.array(decision_variables.to_numpy())
    nan_mask = np.isnan(X_withnan)
    nan_mask_y = []
    for row in nan_mask:
        if True in row:
            nan_mask_y.append(True)
        else:
            nan_mask_y.append(False)


    # Select X and y
    X = X_withnan[~np.array(nan_mask_y)]
    y = output_variable[~np.array(nan_mask_y)]
    

    # Start Training
    random_state = randint(0,len(y))
    X_train, X_test, y_train_real, y_test_real = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # print(y_train)
    # print(y_test)

    if decision_variable_target == 'mean_event':
        classifier = {'1': (-1,-0.2), '2': (-0.2,0), '3':(0,0.2), '4': (0.2,3)}
        classifier_strings = [str(classifier[cls][0]) + '<x<' + str(classifier[cls][1]) for cls in classifier]
    elif decision_variable_target == 'max_price':
        classifier = {'1': (0,0.05), '2':(0.05,0.2), '3': (0.2,3)}
        classifier_strings = [str(classifier[cls][0]) + '<x<' + str(classifier[cls][1]) for cls in classifier]
    elif decision_variable_target == 'min_price':
        classifier = {'1': (-1,-0.2), '2': (-0.2,-0.05), '3':(-0.05,0.0001)}
        classifier_strings = [str(classifier[cls][0]) + '<x<' + str(classifier[cls][1]) for cls in classifier]
    
    y_train = []
    y_test = []
    
    # encode y_test and y_train
    for y, i in zip(y_train_real, range(len(y_train_real))):
        for cl_key in classifier:
            if y >= classifier[cl_key][0] and y < classifier[cl_key][1]:
                y_train.append(int(cl_key))
                break

    for y, i in zip(y_test_real, range(len(y_test_real))):
        for cl_key in classifier:
            if y >= classifier[cl_key][0] and y < classifier[cl_key][1]:
                y_test.append(int(cl_key))
                break
    
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)


    # Fit Linear Regression
    if model_type == 'linear_regression':
        print('Linear Regression Model')
        model = LinearRegression()
        model.fit(X_train, y_train)
    elif model_type == 'svc':
        print('SVC Model')
        model = SVR(kernel='rbf')  # Puoi scegliere il kernel desiderato
        model.fit(X_train, y_train)
    elif model_type == 'xgboost':
        model = XGBClassifier(n_estimators=50,
                     max_depth=5,
                     max_leaves=64,
                     eta=0.1,
                     reg_lambda=0,
                     tree_method='hist',
                     eval_metric='logloss',
                     use_label_encoder=False,
                     random_state=1000,
                     n_jobs=-1)

        model.fit(X_train,y_train)

    # Predict
    y_pred = model.predict(X_test)
    y_pred = le.inverse_transform(y_pred)

    # x_line = np.linspace(min(y_test), max(y_test), 100)
    # mse = mean_squared_error(y_test, y_pred)
    # print(f"Mean Squared Error: {mse}")
    # plt.scatter(y_test, y_pred)
    # plt.plot(x_line, x_line, 'r--', label="x = y", linewidth=2)  # 'r--' creates a red dashed line
    # plt.xlabel("Valori reali")
    # plt.ylabel("Valori previsti")
    # plt.title("Confronto tra valori reali e previsti")
    # plt.show()

    cm = confusion_matrix(y_test, y_pred)
    df_cm = pd.DataFrame(cm, index = [i for i in classifier_strings], columns = [i for i in classifier_strings])
    # ax = plt.figure(figsize = (10,7))
    # ax.plt.xlabel("Valori reali")
    # ax.plt.ylabel("Valori previsti")
    # sn.heatmap(df_cm, annot=True)
    # accuracy_score(y_test, y_pred)

    ax= plt.subplot()
    sn.heatmap(df_cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation
    # labels, title and ticks
    ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels')
    ax.set_title(f'Confusion Matrix for {decision_variable_target}')
    #accuracy_score(y_test, y_pred)

# %%
model_type = 'linear_regression'
model_type = 'svc'
model_type = 'xgboost'
decision_variable_target = 'mean_event'
test_size=0.2
PriceVariation_analysis(df, model_type=model_type, decision_variable_target=decision_variable_target, test_size=test_size)
