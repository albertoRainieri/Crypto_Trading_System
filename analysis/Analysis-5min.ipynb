# %%
from Functions3 import main_instant_trigger
from time import sleep

buy_vol_5m_Buy_List=[0.6, 0.7, 0.8, 0.9, 0.95, 0.98]
vol_5m_Buy_List=[30,50,80,100,150,200]
timeframe = [15, 30, 60, 120, 240, 360, 720, 1440]
INTEGRATION=False
analysis_timeframe=10

for i in range(8):
  iteration = i+1
  print(f'ITERATION {iteration}')
  main_instant_trigger(buy_vol_5m_Buy_List=buy_vol_5m_Buy_List,vol_5m_Buy_List=vol_5m_Buy_List,
                        timeframe=timeframe, analysis_timeframe=analysis_timeframe, INTEGRATION=False)
  #sleep(30)

# %%
# INTEGRATION
from Functions3 import main_instant_trigger
from time import sleep

buy_vol_5m_Buy_List=[0.99]
vol_5m_Buy_List=[30,50,80,100,150,200]
timeframe = [720, 1440]
INTEGRATION=True
analysis_timeframe=40

for i in range(1):
  iteration = i+1
  print(f'ITERATION {iteration}')
  main_instant_trigger(buy_vol_5m_Buy_List=buy_vol_5m_Buy_List,vol_5m_Buy_List=vol_5m_Buy_List,
                        timeframe=timeframe, analysis_timeframe=analysis_timeframe, INTEGRATION=INTEGRATION)
  sleep(10)
# Out:
# ITERATION 1
# INTEGRATION ANALYSIS STARTED
# /Users/albertorainieri/Projects/Personal/analysis/benchmark_json/benchmark-6-12-2023 exists. Loading the file...
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-07-06-00-01.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-11-04-16-51.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-07-02-06-01.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-10-31-21-6.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-06-11-14-20.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-06-19-10-45.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-08-05-12-36.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-09-13-02-16.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-07-21-05-56.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-09-28-07-24.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-07-25-03-40.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-09-01-16-40.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-09-09-07-4.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-10-09-20-4.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-08-25-02-43.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-08-01-19-8.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-07-13-12-48.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-08-09-06-35.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-08-21-06-48.json
# Retrieving data from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-05-07-0-0.json
# Retrieving data from /Users/albertorainieri/Projects/Personal/analysis/json/data-2023-06-15-14-20.json
# Length of data argument 0: 44
# Length of data argument 1: 44
# Length of data argument 2: 44
# Length of data argument 3: 44
# Length of data argument 4: 44
# Length of data argument 5: 44
# Length of data argument 6: 44
# Length of data argument 7: 43
# Data for 351 coins are loaded from 2023-05-11T00:00:05.857211 to 2023-06-19T10:44:02.297790
# Events from 2023-05-11T00:00:00 to 2023-06-18T10:44:02.297790 will be analyzed
# Total Number of combinations: 12
# Slice 1 has started
# 1/10 of data analyzed
# 1/4 of data analyzed
# 1/2 of data analyzed
# Slice 2 has started
# 3/4 of data analyzed
# size of shared_data_value before completion of 1: 0.001449 Mb; Number of events saved: 5
# size of shared_data_value before completion of 2: 0.001449 Mb; Number of events saved: 5
# Slice 3 has started
# Slice 4 has started
# size of shared_data_value before completion of 3: 0.001737 Mb; Number of events saved: 7
# Slice 5 has started
# size of shared_data_value before completion of 4: 0.001737 Mb; Number of events saved: 7
# Slice 6 has started
# size of shared_data_value before completion of 5: 0.001737 Mb; Number of events saved: 7
# Slice 7 has started
# size of shared_data_value before completion of 6: 0.002579 Mb; Number of events saved: 13
# Slice 8 has started
# size of shared_data_value before completion of 7: 0.003741 Mb; Number of events saved: 21
# size of shared_data_value before completion of 8: 0.003741 Mb; Number of events saved: 21
# pool closed
# pool joined
# analysis_json is loaded with file_path: /Users/albertorainieri/Projects/Personal/analysis/analysis_json_v3/analysis.json
# new data was jsonized

# %%
from Functions3 import download_show_output
import pandas as pd

minimum_event_number=700
minimum_event_number_list = [minimum_event_number]
minimum_coin_number=1
mean_threshold= 0
frequency_threshold=0
best_coins_timeframe=2
early_validation=False
max_threshold = 4
lb_threshold = -15
std_multiplier = 200

output, info = download_show_output(minimum_event_number, minimum_coin_number, mean_threshold, frequency_threshold, max_threshold, lb_threshold, std_multiplier,
                                     best_coins_timeframe=best_coins_timeframe, early_validation=early_validation)

df = pd.DataFrame(output).transpose()
df.sort_values(by=['mean'], ascending=False)
# Out:
# Downloading /Users/albertorainieri/Projects/Personal/analysis/analysis_json_v3/analysis.json
# Download completed in 0.13 seconds
#                                           best_max  frequency/month  mean  \
# buy_vol_5m:0.95/vol_5m:30/timeframe:1440    134.62           124.94  0.14
#
#                                           mean_max  mean_min  n_coins  \
# buy_vol_5m:0.95/vol_5m:30/timeframe:1440      4.17     -2.51    160.0
#
#                                           n_events  perc10_max  perc25_max  \
# buy_vol_5m:0.95/vol_5m:30/timeframe:1440     708.0        0.23        0.76
#
#                                           perc50_max  perc75_max  perc90_max  \
# buy_vol_5m:0.95/vol_5m:30/timeframe:1440        2.08        4.12        8.55
#
#                                            std  std_max
# buy_vol_5m:0.95/vol_5m:30/timeframe:1440  2.55     9.47

# %%
from Functions3 import inspect_key
from IPython.display import display, Markdown

percentile_list = [99,90,75,50,25,15]

s1="buy_vol_5m:0.6/vol_5m:150/timeframe:1440"
s2="buy_vol_5m:0.6/vol_5m:100/timeframe:1440"
s3="buy_vol_5m:0.6/vol_5m:80/timeframe:720"
s4="buy_vol_5m:0.6/vol_5m:200/timeframe:1440"
s5="buy_vol_5m:0.9/vol_5m:80/timeframe:1440" #best so far 6-dec-2023
s6="buy_vol_5m:0.95/vol_5m:30/timeframe:1440"

inspect_key(s4, percentile_list, showPercentile=None, DISCOVER=False)
# Out:
# Downloading /Users/albertorainieri/Projects/Personal/analysis/analysis_json_v3/analysis.json
# Download completed in 0.1 seconds
# There is only one JSON associated with buy_vol_5m_0.6_vol_5m_200_timeframe_1440
# Timeseries has been downloaded
#     index  max_bottom  n_events  minimum_to_max_99  minimum_to_max_90  \
# 0  99perc    1.083107         6                0.0                0.0
# 1  90perc    0.310753        50                0.0                0.0
# 2  75perc    0.118412        83                0.0                0.0
# 3  50perc    0.040984       138                0.0                0.0
# 4  25perc    0.008772       138                0.0                0.0
# 5  15perc    0.000000       138                0.0                0.0
#
#    minimum_to_max_75  minimum_to_max_50  minimum_to_max_25  minimum_to_max_15  \
# 0              0.000             -0.018             -0.043             -0.047
# 1             -0.003             -0.016             -0.066             -0.085
# 2              0.000             -0.022             -0.056             -0.076
# 3             -0.001             -0.016             -0.044             -0.062
# 4              0.000             -0.008             -0.030             -0.047
# 5              0.000              0.000              0.000             -0.008
#
#    biggest_drop_99  biggest_drop_90  biggest_drop_75  biggest_drop_50  \
# 0             0.50             0.45             0.35             0.24
# 1             0.44             0.36             0.26             0.16
# 2             0.24             0.18             0.14             0.08
# 3             0.22             0.11             0.07             0.04
# 4             0.16             0.07             0.04             0.02
# 5             0.09             0.04             0.02             0.00
#
#    biggest_drop_25  biggest_drop_15  minutes_to_max_99  minutes_to_max_90  \
# 0             0.20             0.19               1365               1312
# 1             0.11             0.08               1430               1370
# 2             0.05             0.04               1426               1218
# 3             0.02             0.01               1395               1132
# 4             0.00             0.00               1377               1030
# 5             0.00             0.00               1345               1086
#
#    minutes_to_max_75  minutes_to_max_50  minutes_to_max_25  minutes_to_max_15
# 0               1227               1086                985                750
# 1                968                456                103                 33
# 2                738                263                 43                 28
# 3                593                 65                 11                  4
# 4                152                 10                  2                  1
# 5                 23                  3                  1                  1

# %%
from Functions3 import RiskConfiguration

optimized_gain_threshold = -3
mean_gain_threshold = -3
DISCOVER=False
group_coins = False
delete_X_perc = False

riskmanagement_conf = (minimum_event_number_list, minimum_coin_number, mean_threshold, lb_threshold, frequency_threshold, group_coins, best_coins_timeframe, std_multiplier, early_validation)
df, none_riskmanagement_path  = RiskConfiguration(info, riskmanagement_conf, optimized_gain_threshold, mean_gain_threshold, delete_X_perc=delete_X_perc, DISCOVER=DISCOVER)
df
# Out:
# 1 keys will be analyzed in terms of risk configuration
# buy_vol_5m:0.95/vol_5m:30/timeframe:1440
# ITERATION 1/1 has started
# Number of combinations 1920
# There is only one JSON associated with buy_vol_5m_0.95_vol_5m_30_timeframe_1440
# Timeseries has been downloaded
# Dividing the dataset for multiprocessing
# 0 events have been discarded for False percentile
# Starting the multiprocessing Task for Risk Configuration
# 1/10 of data analyzed
# 1/4 of data analyzed
# 1/2 of data analyzed
# 3/4 of data analyzed
# Multiprocessing Task is Completed
# NaN values detected, check this path  /Users/albertorainieri/Projects/Personal/analysis/logs/2023-12-07T08:51:50-nanreplaced.txt
# 282.25 euro of profit for an investment of 100 euro per event (total of 704 events). risk_retracement_zone:0.15_retracement:0.1_retracement_step:0.15_loss_zone:-0.015_step_loss:0.01 with 0.4 %
# 611.2516050338745 seconds spent to run wrap_analyze_events
#                                        keys risk_retracement_zone  \
# 0  buy_vol_5m:0.95/vol_5m:30/timeframe:1440                  0.15
#
#   retracement_% retracement_gain loss_zone step_loss  optimized_gain  \
# 0           0.1             0.15    -0.015      0.01             0.4
#
#    optimized_std  mean_gain  median_gain  std_gain  frequency  n_events
# 0            5.8       0.24         0.24       5.9     124.94       708
