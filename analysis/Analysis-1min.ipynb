# %%
from Functions2 import main_instant_trigger

buy_vol_1m_Buy_List=[0.85, 0.9, 0.95]
vol_1m_Buy_List=[2,3,4,6]
sell_vol_Sell_List=[0.5, 0.4]
sell_vol_Sell_field_List=['buy_vol_30m', 'buy_vol_60m', 'buy_vol_3h', 'buy_vol_6h']
previous_volume_activity_List=[1.2, 0.8]
price_changes_List = [0.02, 0.04]
INTEGRATION=False
analysis_timeframe=7

for i in range(4):
  main_instant_trigger(buy_vol_1m_Buy_List=buy_vol_1m_Buy_List,vol_1m_Buy_List=vol_1m_Buy_List,
                        sell_vol_Sell_List=sell_vol_Sell_List, sell_vol_Sell_field_List=sell_vol_Sell_field_List,
                          previous_volume_activity_List=previous_volume_activity_List, price_changes_List=price_changes_List, analysis_timeframe=analysis_timeframe, INTEGRATION=False)
# Out:
# /Users/albertorainieri/Projects/Personal/analysis/benchmark_json/benchmark-9-10-2023 exists. Loading the file...
# /Users/albertorainieri/Projects/Personal/analysis/benchmark_json/benchmark-9-10-2023 exists. Loading the file...
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-07-05-2023-0-0.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-07-06-2023-19-49.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-11-06-2023-14-20.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-15-06-2023-14-20.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-19-06-2023-10-45.json
# Nothing to retrieve from /Users/albertorainieri/Projects/Personal/analysis/json/data-23-06-2023-08-02.json
# Retrieving data from /Users/albertorainieri/Projects/Personal/analysis/json/data-27-06-2023-04-18.json
# ...

# %%
from Functions2 import download_show_output
import pandas as pd

minimum_event_number=5
minimum_coin_number=1
mean_threshold=0
frequency_threshold=0
best_coins_volatility=10
early_validation=False
group_coins=True

output, info = download_show_output(minimum_event_number, minimum_coin_number, mean_threshold, frequency_threshold, group_coins=group_coins, best_coins_volatility=best_coins_volatility, early_validation=early_validation)

df = pd.DataFrame(output).transpose()
df.sort_values(by=['mean'], ascending=False)
# Out:
# ...
# Download completed in 0.64 seconds
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#                                                     mean  max_return  \
# vol1m:4/buyvol1m:0.85/buy_vol_3h:0.4/prevActivi...  0.09        0.19
# vol1m:6/buyvol1m:0.85/buy_vol_6h:0.4/prevActivi...  0.07        0.13
# vol1m:3/buyvol1m:0.85/buy_vol_6h:0.4/prevActivi...  0.07        0.13
# vol1m:4/buyvol1m:0.85/buy_vol_6h:0.4/prevActivi...  0.07        0.13
# vol1m:3/buyvol1m:0.85/buy_vol_3h:0.4/prevActivi...  0.05        0.12
# vol1m:4/buyvol1m:0.85/buy_vol_3h:0.5/prevActivi...  0.05        0.08
# vol1m:4/buyvol1m:0.85/buy_vol_6h:0.4/prevActivi...  0.05        0.16
# ...

# %%
output
# Out:
# {}
